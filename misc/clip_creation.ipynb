# %%
input_path = r"D:\Akash\Work\AI\Datasets\v360\_video"
output_path = r"\\10.0.20.60\share\AI\data\_test_data\評価データ作成_202501\定性評価\fiftyone\samples"

v360_name = ["v360_test1", "v360_test2", "v360_test3", "v360_test4", "v360_test5", "v360_test6", "v360_test7", "v360_test8", "v360_test9", "v360_test10", "v360_test11", "v360_test12", "v360_test13"]
quad_name = ["leftdown", "rightdown", "leftup", "righttup"]

v360 = 2
quad = 2
start_time = "00:02:03"
end_time = "00:02:06"

# !ffmpeg -ss {start_time} -to {end_time} -i {input_path}/{v360_name[v360]}/{quad_name[quad]}.mp4 -c:v libx264 -crf 23 -preset fast -c:a aac -b:a 128k {output_path}/{v360_name[v360]}_{quad_name[quad]}_{start_time.replace(":", "")}_{end_time.replace(":", "")}.mp4
# Out:
# ffmpeg version N-115582-gd55f5cba7b-20240606 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (crosstool-NG 1.26.0.65_ecc5e41)
# ...
